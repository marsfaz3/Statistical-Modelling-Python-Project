# %% [markdown]
# # CityBikes

# %% [markdown]
# Your tasks are as follows:
# 1. Explore the structure of the API, query the API and understand the data returned.
# 2. Choose a city covered by the CityBikes API and retrieve all available bike stations in that city.
# 3. For each bike station, use the API to call the latitude, longitude and number of bikes.
# 4. Parse the JSON object into a Pandas dataframe.
#
# Complete the **city_bikes.ipynb** notebook to demonstrate how you executed the tasks above.

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
import os
import pandas as pd
from pprint import pprint # this will display the data in a structured, more readable manner


href = "bixi-toronto"
url = "http://api.citybik.es/v2/networks/" + href

# Create dictionary for headers
headers = {"Accept": "application/json"}

bikes = requests.get(url, headers=headers)

print(bikes.json())
# Out:
# {'network': {'id': 'bixi-toronto', 'name': 'Bike Share Toronto', 'location': {'latitude': 43.653226, 'longitude': -79.3831843, 'city': 'Toronto, ON', 'country': 'CA'}, 'href': '/v2/networks/bixi-toronto', 'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'], 'gbfs_href': 'https://tor.publicbikesystem.net/ube/gbfs/v1/', 'stations': [{'id': '009f180cf35ae1285733d98ccf058313', 'name': 'Summerhill Ave / Maclennan Ave', 'latitude': 43.685924, 'longitude': -79.376304, 'timestamp': '2025-04-15T21:03:40.155472Z', 'free_bikes': 0, 'empty_slots': 11, 'extra': {'uid': '7488', 'renting': 1, 'returning': 1, 'last_updated': 1744750915, 'address': 'Summerhill Ave / Maclennan Ave', 'post_code': 'M4M 2Z9', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 0, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': None, 'slots': 11, 'rental_uris': {}}}, {'id': '010507feed5b8d87c40cd95933ed5654', 'name': 'Queen St E / Joseph Duggan Rd', 'latitude': 43.6677628, 'longitude': -79.30811709999999, 'timestamp': '2025-04-15T21:03:40.159363Z', 'free_bikes': 12, 'empty_slots': 7, 'extra': {'uid': '7695', 'renting': 1, 'returning': 1, 'last_updated': 1744750998, 'address': 'Queen St E and Joseph Duggan Rd', 'post_code': 'M4L 3Y2', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 12, 'payment': ['key', 'transitcard', 'phone'], 'payment-terminal': False, 'altitude': 0.0, 'slots': 19, 'rental_uris': {}}}, {'id': '0153756b9e136b96e730aaa2f048227f', 'name': 'Victoria Park Ave / Danforth Ave', 'latitude': 43.691468, 'longitude': -79.288619, 'timestamp': '2025-04-15T21:03:40.157283Z', 'free_bikes': 2, 'empty_slots': 17, 'extra': {'uid': '7611', 'renting': 1, 'returning': 1, 'last_updated': 1744750898, 'address': 'Victoria Park Ave / Danforth Ave', 'post_code': 'M4C 1N2', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 2, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 19, 'rental_uris': {}}}, {'id': '019e5937c3fc120cee906770bca8fa69', 'name': 'Navy Wharf Crt / Bremner Blvd', 'latitude': 43.640722, 'longitude': -79.391051, 'timestamp': '2025-04-15T21:03:40.127576Z', 'free_bikes': 2, 'empty_slots': 4, 'extra': {'uid': '7054', 'renting': 1, 'returning': 1, 'last_updated': 1744750952, 'address': 'Navy Wharf Ct. / Bremner Blvd.', 'has_ebikes': True, 'ebikes': 1, 'normal_bikes': 1, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': None, 'slots': 9, 'rental_uris': {}}}, {'id': '01caf8b12874b091f2fccc3818e3c72e', 'name': '420 Wellington St W', 'latitude': 43.643834, 'longitude': -79.396649, 'timestamp': '2025-04-15T21:03:40.128763Z', 'free_bikes': 13, 'empty_slots': 2, 'extra': {'uid': '7123', 'renting': 1, 'returning': 1, 'last_updated': 1744750881, 'address': '420 Wellington St W', 'has_ebikes': True, 'ebikes': 2, 'normal_bikes': 11, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': None, 'slots': 15, 'rental_uris': {}}}, {'id': '022818120bd4e5138186fe1ab57f791a', 'name': 'Sentinel Rd / Finch Ave W', 'latitude': 43.76073963892478, 'longitude': -79.5000273116394, 'timestamp': '2025-04-15T21:03:40.167428Z', 'free_bikes': 1, 'empty_slots': 13, 'extra': {'uid': '7873', 'renting': 1, 'returning': 1, 'last_updated': 1744750958, 'address': '390 Sentinel Rd', 'post_code': 'M3J 1V3', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 1, 'payment': ['key', 'transitcard', 'phone'], 'payment-terminal': False, 'altitude': 0.0, 'slots': 14, 'rental_uris': {}}}, {'id': '026bf7c2104a659ef0392f1c22bc6e17', 'name': 'Ross St / Cecil St - SMART', 'latitude': 43.6568254, 'longitude': -79.3966159, 'timestamp': '2025-04-15T21:03:40.156167Z', 'free_bikes': 9, 'empty_slots': 8, 'extra': {'uid': '7546', 'renting': 1, 'returning': 1, 'last_updated': 1744750985, 'address': 'Ross St / Cecil St', 'post_code': 'M5T 1N3', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 9, 'payment': ['key', 'tra ...

# %%
print(bikes.json(), "\n")
# Out:
# {'network': {'id': 'bixi-toronto', 'name': 'Bike Share Toronto', 'location': {'latitude': 43.653226, 'longitude': -79.3831843, 'city': 'Toronto, ON', 'country': 'CA'}, 'href': '/v2/networks/bixi-toronto', 'company': ['Motivate International, Inc.', 'PBSC Urban Solutions'], 'gbfs_href': 'https://tor.publicbikesystem.net/ube/gbfs/v1/', 'stations': [{'id': '009f180cf35ae1285733d98ccf058313', 'name': 'Summerhill Ave / Maclennan Ave', 'latitude': 43.685924, 'longitude': -79.376304, 'timestamp': '2025-04-15T21:03:40.155472Z', 'free_bikes': 0, 'empty_slots': 11, 'extra': {'uid': '7488', 'renting': 1, 'returning': 1, 'last_updated': 1744750915, 'address': 'Summerhill Ave / Maclennan Ave', 'post_code': 'M4M 2Z9', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 0, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': None, 'slots': 11, 'rental_uris': {}}}, {'id': '010507feed5b8d87c40cd95933ed5654', 'name': 'Queen St E / Joseph Duggan Rd', 'latitude': 43.6677628, 'longitude': -79.30811709999999, 'timestamp': '2025-04-15T21:03:40.159363Z', 'free_bikes': 12, 'empty_slots': 7, 'extra': {'uid': '7695', 'renting': 1, 'returning': 1, 'last_updated': 1744750998, 'address': 'Queen St E and Joseph Duggan Rd', 'post_code': 'M4L 3Y2', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 12, 'payment': ['key', 'transitcard', 'phone'], 'payment-terminal': False, 'altitude': 0.0, 'slots': 19, 'rental_uris': {}}}, {'id': '0153756b9e136b96e730aaa2f048227f', 'name': 'Victoria Park Ave / Danforth Ave', 'latitude': 43.691468, 'longitude': -79.288619, 'timestamp': '2025-04-15T21:03:40.157283Z', 'free_bikes': 2, 'empty_slots': 17, 'extra': {'uid': '7611', 'renting': 1, 'returning': 1, 'last_updated': 1744750898, 'address': 'Victoria Park Ave / Danforth Ave', 'post_code': 'M4C 1N2', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 2, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 19, 'rental_uris': {}}}, {'id': '019e5937c3fc120cee906770bca8fa69', 'name': 'Navy Wharf Crt / Bremner Blvd', 'latitude': 43.640722, 'longitude': -79.391051, 'timestamp': '2025-04-15T21:03:40.127576Z', 'free_bikes': 2, 'empty_slots': 4, 'extra': {'uid': '7054', 'renting': 1, 'returning': 1, 'last_updated': 1744750952, 'address': 'Navy Wharf Ct. / Bremner Blvd.', 'has_ebikes': True, 'ebikes': 1, 'normal_bikes': 1, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': None, 'slots': 9, 'rental_uris': {}}}, {'id': '01caf8b12874b091f2fccc3818e3c72e', 'name': '420 Wellington St W', 'latitude': 43.643834, 'longitude': -79.396649, 'timestamp': '2025-04-15T21:03:40.128763Z', 'free_bikes': 13, 'empty_slots': 2, 'extra': {'uid': '7123', 'renting': 1, 'returning': 1, 'last_updated': 1744750881, 'address': '420 Wellington St W', 'has_ebikes': True, 'ebikes': 2, 'normal_bikes': 11, 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': None, 'slots': 15, 'rental_uris': {}}}, {'id': '022818120bd4e5138186fe1ab57f791a', 'name': 'Sentinel Rd / Finch Ave W', 'latitude': 43.76073963892478, 'longitude': -79.5000273116394, 'timestamp': '2025-04-15T21:03:40.167428Z', 'free_bikes': 1, 'empty_slots': 13, 'extra': {'uid': '7873', 'renting': 1, 'returning': 1, 'last_updated': 1744750958, 'address': '390 Sentinel Rd', 'post_code': 'M3J 1V3', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 1, 'payment': ['key', 'transitcard', 'phone'], 'payment-terminal': False, 'altitude': 0.0, 'slots': 14, 'rental_uris': {}}}, {'id': '026bf7c2104a659ef0392f1c22bc6e17', 'name': 'Ross St / Cecil St - SMART', 'latitude': 43.6568254, 'longitude': -79.3966159, 'timestamp': '2025-04-15T21:03:40.156167Z', 'free_bikes': 9, 'empty_slots': 8, 'extra': {'uid': '7546', 'renting': 1, 'returning': 1, 'last_updated': 1744750985, 'address': 'Ross St / Cecil St', 'post_code': 'M5T 1N3', 'has_ebikes': True, 'ebikes': 0, 'normal_bikes': 9, 'payment': ['key', 'tra ...

# %%
pprint(bikes.json())
# Out:
# {'network': {'company': ['Motivate International, Inc.',
#                          'PBSC Urban Solutions'],
#              'gbfs_href': 'https://tor.publicbikesystem.net/ube/gbfs/v1/',
#              'href': '/v2/networks/bixi-toronto',
#              'id': 'bixi-toronto',
#              'location': {'city': 'Toronto, ON',
#                           'country': 'CA',
#                           'latitude': 43.653226,
#                           'longitude': -79.3831843},
#              'name': 'Bike Share Toronto',
#              'stations': [{'empty_slots': 11,
#                            'extra': {'address': 'Summerhill Ave / Maclennan '
#                                                 'Ave',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750915,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M4M 2Z9',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7488'},
#                            'free_bikes': 0,
#                            'id': '009f180cf35ae1285733d98ccf058313',
#                            'latitude': 43.685924,
#                            'longitude': -79.376304,
#                            'name': 'Summerhill Ave / Maclennan Ave',
#                            'timestamp': '2025-04-15T21:03:40.155472Z'},
#                           {'empty_slots': 7,
#                            'extra': {'address': 'Queen St E and Joseph Duggan '
#                                                 'Rd',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750998,
#                                      'normal_bikes': 12,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M4L 3Y2',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7695'},
#                            'free_bikes': 12,
#                            'id': '010507feed5b8d87c40cd95933ed5654',
#                            'latitude': 43.6677628,
#                            'longitude': -79.30811709999999,
#                            'name': 'Queen St E / Joseph Duggan Rd',
#                            'timestamp': '2025-04-15T21:03:40.159363Z'},
#                           {'empty_slots': 17,
#                            'extra': {'address': 'Victoria Park Ave / Danforth '
#                                                 'Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750898,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M4C 1N2',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7611'},
#                            'free_bikes': 2,
#                            'id': '0153756b9e136b96e730aaa2f048227f',
#                            'latitude': 43.691468,
#                            'longitude': -79.288619,
#                            'name': 'Victoria Park Ave / Danforth Ave',
#                            'timestamp': '2025-04-15T21:03:40.157283Z'},
#                           {'empty_slots': 4,
#                            'extra': {'address': 'Navy Wharf Ct. / Bremner '
#                                                 'Blvd.',
#                                      'altitude': None,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750952,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 9,
#                                      'uid': '7054'},
#                            'free_bikes': 2,
#                            'id': '019e5937c3fc120cee906770bca8fa69',
#                            'latitude': 43.640722,
#                            'longitude': -79.391051,
#                            'name': 'Navy Wharf Crt / Bremner Blvd',
#                            'timestamp': '2025-04-15T21:03:40.127576Z'},
#                           {'empty_slots': 2,
#                            'extra': {'address': '420 Wellington St W',
#                                      'altitude': None,
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750881,
#                                      'normal_bikes': 11,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7123'},
#                            'free_bikes': 13,
#                            'id': '01caf8b12874b091f2fccc3818e3c72e',
#                            'latitude': 43.643834,
#                            'longitude': -79.396649,
#                            'name': '420 Wellington St W',
#                            'timestamp': '2025-04-15T21:03:40.128763Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': '390 Sentinel Rd',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750958,
#                                      'normal_bikes': 1,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M3J 1V3',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 14,
#                                      'uid': '7873'},
#                            'free_bikes': 1,
#                            'id': '022818120bd4e5138186fe1ab57f791a',
#                            'latitude': 43.76073963892478,
#                            'longitude': -79.5000273116394,
#                            'name': 'Sentinel Rd / Finch Ave W',
#                            'timestamp': '2025-04-15T21:03:40.167428Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'Ross St / Cecil St',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750985,
#                                      'normal_bikes': 9,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M5T 1N3',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 18,
#                                      'uid': '7546'},
#                            'free_bikes': 9,
#                            'id': '026bf7c2104a659ef0392f1c22bc6e17',
#                            'latitude': 43.6568254,
#                            'longitude': -79.3966159,
#                            'name': 'Ross St / Cecil St - SMART',
#                            'timestamp': '2025-04-15T21:03:40.156167Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'York University Station',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750957,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M3J',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7679'},
#                            'free_bikes': 0,
#                            'id': '02d90c8ede19da66083e0d0e14d17258',
#                            'latitude': 43.7741,
#                            'longitude': -79.5005,
#                            'name': 'York University Station (North)',
#                            'timestamp': '2025-04-15T21:03:40.159151Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'Dundas St W / Yonge St',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750927,
#                                      'normal_bikes': 18,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 31,
#                                      'uid': '7038'},
#                            'free_bikes': 18,
#                            'id': '02feaaef65cff4671fb1935179895659',
#                            'latitude': 43.656094,
#                            'longitude': -79.381484,
#                            'name': 'Dundas St W / Yonge St',
#                            'timestamp': '2025-04-15T21:03:40.126870Z'},
#                           {'empty_slots': 23,
#                            'extra': {'address': 'Seaton St / Dundas St E',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750939,
#                                      'normal_bikes': 9,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 32,
#                                      'uid': '7109'},
#                            'free_bikes': 9,
#                            'id': '033dd75f330fec10400341177c68036e',
#                            'latitude': 43.658777,
#                            'longitude': -79.369596,
#                            'name': 'Seaton St / Dundas St E - SMART',
#                            'timestamp': '2025-04-15T21:03:40.128359Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'Euclid Ave / Herrick St',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750989,
#                                      'normal_bikes': 0,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M6G 2T4',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 16,
#                                      'uid': '7537'},
#                            'free_bikes': 1,
#                            'id': '03b565f085260e768988cd216fbeeef4',
#                            'latitude': 43.661559,
#                            'longitude': -79.413845,
#                            'name': 'Euclid Ave / Herrick St - SMART',
#                            'timestamp': '2025-04-15T21:03:40.156038Z'},
#                           {'empty_slots': 5,
#                            'extra': {'address': "Wellesley St W / Queen's Park "
#                                                 'Cres',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750957,
#                                      'normal_bikes': 13,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 18,
#                                      'uid': '7008'},
#                            'free_bikes': 13,
#                            'id': '03cb067499bb9bc86cf0c884edb403bc',
#                            'latitude': 43.663376,
#                            'longitude': -79.392125,
#                            'name': "Wellesley St W / Queen's Park Cres",
#                            'timestamp': '2025-04-15T21:03:40.125818Z'},
#                           {'empty_slots': 17,
#                            'extra': {'address': '144 Harrison St ',
#                                      'altitude': None,
#                                      'ebikes': 33,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750889,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 51,
#                                      'uid': '7249'},
#                            'free_bikes': 34,
#                            'id': '044fd938d016b91837e9b02be913b5c7',
#                            'latitude': 43.651145,
#                            'longitude': -79.423742,
#                            'name': '144 Harrison St',
#                            'timestamp': '2025-04-15T21:03:40.130150Z'},
#                           {'empty_slots': 20,
#                            'extra': {'address': 'Wellington St W / Bay St',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750903,
#                                      'normal_bikes': 34,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 55,
#                                      'uid': '7052'},
#                            'free_bikes': 34,
#                            'id': '045a7a6b973238dc76bc058e4f33f143',
#                            'latitude': 43.647259,
#                            'longitude': -79.379878,
#                            'name': 'Wellington St W / Bay St',
#                            'timestamp': '2025-04-15T21:03:40.127556Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'Sunnyside Ave / The Queensway '
#                                                 '- SMART',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744751001,
#                                      'normal_bikes': 4,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M6R 1B4',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7496'},
#                            'free_bikes': 4,
#                            'id': '049156f7c0e19a53a77d8310d93eed0c',
#                            'latitude': 43.6397,
#                            'longitude': -79.44865,
#                            'name': 'Sunnyside Ave / The Queensway - SMART',
#                            'timestamp': '2025-04-15T21:03:40.155557Z'},
#                           {'empty_slots': 7,
#                            'extra': {'address': '161 Bleecker St (South of '
#                                                 'Wellesley)',
#                                      'altitude': 0.0,
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750908,
#                                      'normal_bikes': 14,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7071'},
#                            'free_bikes': 16,
#                            'id': '049c76540151608ec55bfcd0e1748f41',
#                            'latitude': 43.666233,
#                            'longitude': -79.373327,
#                            'name': '161 Bleecker St (South of Wellesley)',
#                            'timestamp': '2025-04-15T21:03:40.127704Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Bay St / Scollard St',
#                                      'altitude': None,
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750979,
#                                      'normal_bikes': 3,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M5R 0A1',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7127'},
#                            'free_bikes': 5,
#                            'id': '04cadbe0f9b27f89f5fa6f6dbdea0883',
#                            'latitude': 43.672152,
#                            'longitude': -79.39018,
#                            'name': 'Bay St / Scollard St',
#                            'timestamp': '2025-04-15T21:03:40.128801Z'},
#                           {'empty_slots': 14,
#                            'extra': {'address': 'Pape Ave / Gamble Ave',
#                                      'altitude': None,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750922,
#                                      'normal_bikes': 4,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7348'},
#                            'free_bikes': 5,
#                            'id': '052763ac927bce9197aa6381f508576f',
#                            'latitude': 43.690237,
#                            'longitude': -79.350119,
#                            'name': 'Pape Ave / Gamble Ave',
#                            'timestamp': '2025-04-15T21:03:40.130971Z'},
#                           {'empty_slots': 0,
#                            'extra': {'address': 'Queen St E / Hammersmith Ave',
#                                      'altitude': None,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750998,
#                                      'normal_bikes': 10,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7315'},
#                            'free_bikes': 11,
#                            'id': '05d7abba295be4af9e74ca3ec241ebd7',
#                            'latitude': 43.671349,
#                            'longitude': -79.29451,
#                            'name': 'Queen St E / Hammersmith Ave',
#                            'timestamp': '2025-04-15T21:03:40.130660Z'},
#                           {'empty_slots': 5,
#                            'extra': {'address': 'Walnut Ave / Queen St W',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750974,
#                                      'normal_bikes': 9,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M6J 1G4',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7534'},
#                            'free_bikes': 10,
#                            'id': '068f5330e49bd7236864c7cbf904813f',
#                            'latitude': 43.645469,
#                            'longitude': -79.411084,
#                            'name': 'Walnut Ave / Queen St W',
#                            'timestamp': '2025-04-15T21:03:40.156006Z'},
#                           {'empty_slots': 2,
#                            'extra': {'address': 'Queen St E / Pape Ave',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750862,
#                                      'normal_bikes': 14,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 16,
#                                      'uid': '7287'},
#                            'free_bikes': 14,
#                            'id': '0690f86b4ecb172570d8e08b5f9004c3',
#                            'latitude': 43.661673,
#                            'longitude': -79.337789,
#                            'name': 'Queen St E / Pape Ave - SMART',
#                            'timestamp': '2025-04-15T21:03:40.130484Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Tecumseth St / Tecumseth Pl',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750952,
#                                      'normal_bikes': 2,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M5V 2R8',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '8003'},
#                            'free_bikes': 2,
#                            'id': '06dd97607037897ed24979d9b9cd4bed',
#                            'latitude': 43.642697996199985,
#                            'longitude': -79.4049993694586,
#                            'name': 'Tecumseth St / Tecumseth Pl',
#                            'timestamp': '2025-04-15T21:03:40.169632Z'},
#                           {'empty_slots': 18,
#                            'extra': {'address': 'Davenport Rd / Landsdowne Rd',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750955,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7326'},
#                            'free_bikes': 1,
#                            'id': '071b427d1f3f600d6b9f35ca6576ebe2',
#                            'latitude': 43.671526,
#                            'longitude': -79.44874,
#                            'name': 'Davenport Rd / Lansdowne Ave',
#                            'timestamp': '2025-04-15T21:03:40.130765Z'},
#                           {'empty_slots': 4,
#                            'extra': {'address': 'Eastwood Rd / Coxwell Ave',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750956,
#                                      'normal_bikes': 13,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M4L 3B5',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7445'},
#                            'free_bikes': 13,
#                            'id': '0729b25bcf663b7a2278f01d63b50fcf',
#                            'latitude': 43.673118,
#                            'longitude': -79.318651,
#                            'name': 'Eastwood Rd / Coxwell Ave',
#                            'timestamp': '2025-04-15T21:03:40.154915Z'},
#                           {'empty_slots': 7,
#                            'extra': {'address': 'Fenwood Ht / Kingston Rd',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750984,
#                                      'normal_bikes': 8,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M1M 1P1',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7814'},
#                            'free_bikes': 8,
#                            'id': '07bf4729ad15e9e2d17d072dfb67e6b0',
#                            'latitude': 43.72690169821676,
#                            'longitude': -79.22920396582664,
#                            'name': 'Fenwood Ht / Kingston Rd',
#                            'timestamp': '2025-04-15T21:03:40.166542Z'},
#                           {'empty_slots': 0,
#                            'extra': {'address': 'Rouge Hill GO Station',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750863,
#                                      'normal_bikes': 23,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M1C 5G4',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 25,
#                                      'uid': '7626'},
#                            'free_bikes': 23,
#                            'id': '07c0bbd2b5c108bacb3a32250af2a076',
#                            'latitude': 43.7805505,
#                            'longitude': -79.1301203,
#                            'name': 'Rouge Hill GO Station',
#                            'timestamp': '2025-04-15T21:03:40.157512Z'},
#                           {'empty_slots': 1,
#                            'extra': {'address': 'Lundy Ave / Etienne Brule '
#                                                 'Park',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750934,
#                                      'normal_bikes': 14,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M6S 2R5',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7629'},
#                            'free_bikes': 14,
#                            'id': '080c6cc1f827d976fd75f9ccf53db95c',
#                            'latitude': 43.6625395,
#                            'longitude': -79.5030161,
#                            'name': 'Lundy Ave / Étienne Brûlé Park',
#                            'timestamp': '2025-04-15T21:03:40.157546Z'},
#                           {'empty_slots': 44,
#                            'extra': {'address': 'Bremner Blvd / Rees St',
#                                      'altitude': None,
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750993,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 49,
#                                      'uid': '7018'},
#                            'free_bikes': 3,
#                            'id': '082fdb9cce172f916dde26cc3a543b69',
#                            'latitude': 43.641529,
#                            'longitude': -79.386741,
#                            'name': 'Bremner Blvd / Rees St',
#                            'timestamp': '2025-04-15T21:03:40.126656Z'},
#                           {'empty_slots': 14,
#                            'extra': {'address': 'Willowdale Ave / Bishop Ave ',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750890,
#                                      'normal_bikes': 3,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M2M 3C2',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7970'},
#                            'free_bikes': 3,
#                            'id': '084dc489a2da0c722c17a379c243a12a',
#                            'latitude': 43.78387252467251,
#                            'longitude': -79.40786809814757,
#                            'name': 'Willowdale Ave / Bishop Ave ',
#                            'timestamp': '2025-04-15T21:03:40.169087Z'},
#                           {'empty_slots': 10,
#                            'extra': {'address': 'Plaxton Dr / St Clair Ave E',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750935,
#                                      'normal_bikes': 4,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M4B 1N5',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7830'},
#                            'free_bikes': 4,
#                            'id': '086ae84908444d2c0d0faf35deb1704f',
#                            'latitude': 43.70751755961952,
#                            'longitude': -79.30252066313936,
#                            'name': 'Plaxton Dr / St Clair Ave E',
#                            'timestamp': '2025-04-15T21:03:40.166781Z'},
#                           {'empty_slots': 2,
#                            'extra': {'address': 'Front St W / University Ave '
#                                                 '(2)',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750975,
#                                      'normal_bikes': 17,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7321'},
#                            'free_bikes': 17,
#                            'id': '08b57a79795bbd49a15e4a3692ee924f',
#                            'latitude': 43.6452972,
#                            'longitude': -79.3827914,
#                            'name': 'Front St W / University Ave (2)',
#                            'timestamp': '2025-04-15T21:03:40.130723Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Jarvis St / Richmond St E',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750858,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M5C 2H6',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7475'},
#                            'free_bikes': 7,
#                            'id': '08d867cbed5f08addb01b714700eacf7',
#                            'latitude': 43.652777,
#                            'longitude': -79.372637,
#                            'name': 'Jarvis St / Richmond St E',
#                            'timestamp': '2025-04-15T21:03:40.155300Z'},
#                           {'empty_slots': 22,
#                            'extra': {'address': 'Mortimer Ave / Coxwell Ave',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744751002,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7194'},
#                            'free_bikes': 0,
#                            'id': '09007b5f868cd54be0f040f9a9a75c42',
#                            'latitude': 43.690564,
#                            'longitude': -79.326319,
#                            'name': 'Mortimer Ave / Coxwell Ave',
#                            'timestamp': '2025-04-15T21:03:40.129636Z'},
#                           {'empty_slots': 12,
#                            'extra': {'address': 'Dundas St E / River St',
#                                      'altitude': 0.0,
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750968,
#                                      'normal_bikes': 4,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 18,
#                                      'uid': '7796'},
#                            'free_bikes': 6,
#                            'id': '092cb5f641f627d7b43e321542ccc066',
#                            'latitude': 43.661152,
#                            'longitude': -79.358505,
#                            'name': 'Dundas St E / River St',
#                            'timestamp': '2025-04-15T21:03:40.166309Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': '2236 St Clair Ave W',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750919,
#                                      'normal_bikes': 1,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M6N 5C1',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7903'},
#                            'free_bikes': 1,
#                            'id': '0a28cd61ad950b8ebc49d08f1b3936ee',
#                            'latitude': 43.670042134416704,
#                            'longitude': -79.4789424818056,
#                            'name': 'St Clair Ave W / Symes Rd',
#                            'timestamp': '2025-04-15T21:03:40.167996Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Yarmouth Rd / Christie St',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750956,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7149'},
#                            'free_bikes': 0,
#                            'id': '0abdfc3177000757dcd71bd4c8b479ee',
#                            'latitude': 43.67,
#                            'longitude': -79.42083333333333,
#                            'name': 'Yarmouth Rd / Christie St',
#                            'timestamp': '2025-04-15T21:03:40.128988Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'Dufferin Gate',
#                                      'altitude': None,
#                                      'ebikes': 0,
# ...
#                                      'last_updated': 1744750996,
#                                      'normal_bikes': 9,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 23,
#                                      'uid': '7164'},
#                            'free_bikes': 9,
#                            'id': 'fc62f74abe3d79fa430f55f6f56e5e3a',
#                            'latitude': 43.657424,
#                            'longitude': -79.381019,
#                            'name': 'Gould St / Yonge St (TMU)',
#                            'timestamp': '2025-04-15T21:03:40.129224Z'},
#                           {'empty_slots': 19,
#                            'extra': {'address': '406 Oakwood Ave, York, ON M6E '
#                                                 '2W3',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750983,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'L5C 1E4',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7519'},
#                            'free_bikes': 0,
#                            'id': 'fc6389e5eba6c99ed3c0185b65c9cb5c',
#                            'latitude': 43.68827060022711,
#                            'longitude': -79.43937767081853,
#                            'name': '406 Oakwood Ave',
#                            'timestamp': '2025-04-15T21:03:40.155809Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Simcoe St / Queen St W',
#                                      'altitude': None,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750940,
#                                      'normal_bikes': 24,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'm5v1z5',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 39,
#                                      'uid': '7022'},
#                            'free_bikes': 25,
#                            'id': 'fc7fa6476f3fce587eeb9e2200faa005',
#                            'latitude': 43.65049,
#                            'longitude': -79.3873,
#                            'name': 'Simcoe St / Queen St W',
#                            'timestamp': '2025-04-15T21:03:40.126700Z'},
#                           {'empty_slots': 14,
#                            'extra': {'address': 'Cherry Beach Sports Field (55 '
#                                                 'Unwin Ave)',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750903,
#                                      'normal_bikes': 16,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M5A 1A3',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 31,
#                                      'uid': '7345'},
#                            'free_bikes': 16,
#                            'id': 'fca601c1041c34a9c42af38d71e7403a',
#                            'latitude': 43.6408346,
#                            'longitude': -79.3429074,
#                            'name': 'Cherry Beach Sports Fields (55 Unwin Ave)',
#                            'timestamp': '2025-04-15T21:03:40.130939Z'},
#                           {'empty_slots': 36,
#                            'extra': {'address': '925 Brimley Rd',
#                                      'altitude': 0.0,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750966,
#                                      'normal_bikes': 3,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M1P 3E8',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 39,
#                                      'uid': '7957'},
#                            'free_bikes': 3,
#                            'id': 'fd7c0cadeb907434f002aadc42a88554',
#                            'latitude': 43.75404854399297,
#                            'longitude': -79.2553167552948,
#                            'name': 'Brimley Rd / Lawrence Ave E ',
#                            'timestamp': '2025-04-15T21:03:40.168878Z'},
#                           {'empty_slots': 10,
#                            'extra': {'address': 'Dundas St W / Roncesvalles '
#                                                 'Green P',
#                                      'altitude': None,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750933,
#                                      'normal_bikes': 1,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 12,
#                                      'uid': '7229'},
#                            'free_bikes': 2,
#                            'id': 'fe00988a883c9469b82d17221ef1824b',
#                            'latitude': 43.6534268,
#                            'longitude': -79.4512787,
#                            'name': 'Dundas St W / Roncesvalles Ave Green P '
#                                    '-SMART',
#                            'timestamp': '2025-04-15T21:03:40.129955Z'},
#                           {'empty_slots': 2,
#                            'extra': {'address': 'Pottery Rd / Lower Don River '
#                                                 'Trail',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750967,
#                                      'normal_bikes': 12,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M4K 2B9',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7454'},
#                            'free_bikes': 12,
#                            'id': 'fe268f3f2f439d0016dc46605491078e',
#                            'latitude': 43.688148,
#                            'longitude': -79.362101,
#                            'name': 'Pottery Rd / Lower Don River Trail',
#                            'timestamp': '2025-04-15T21:03:40.155045Z'},
#                           {'empty_slots': 1,
#                            'extra': {'address': '457 King St W.',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750893,
#                                      'normal_bikes': 18,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 19,
#                                      'uid': '7323'},
#                            'free_bikes': 18,
#                            'id': 'fe806cf907683c67f4d2899eb4123f00',
#                            'latitude': 43.6452091,
#                            'longitude': -79.3960744,
#                            'name': '457 King St W',
#                            'timestamp': '2025-04-15T21:03:40.130744Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Danforth Ave / Coxwell Ave',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750983,
#                                      'normal_bikes': 3,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7088'},
#                            'free_bikes': 4,
#                            'id': 'fe97ae335b31b6c455f340f397904d38',
#                            'latitude': 43.683378,
#                            'longitude': -79.322961,
#                            'name': 'Danforth Ave / Coxwell Ave',
#                            'timestamp': '2025-04-15T21:03:40.127839Z'},
#                           {'empty_slots': 10,
#                            'extra': {'address': 'Bloor St W / Brock Av',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750998,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'post_code': 'M6H 1M9',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 11,
#                                      'uid': '7656'},
#                            'free_bikes': 1,
#                            'id': 'fea3f9dfbcc18225728f10913c5d3d5b',
#                            'latitude': 43.6589882,
#                            'longitude': -79.438715,
#                            'name': 'Bloor St W / Brock Ave',
#                            'timestamp': '2025-04-15T21:03:40.157929Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'Wells Hill Ave / St Clair Ave '
#                                                 'W',
#                                      'altitude': None,
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750955,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 15,
#                                      'uid': '7363'},
#                            'free_bikes': 0,
#                            'id': 'ffc954e6f4228f59169c040483ebcc3a',
#                            'latitude': 43.683351,
#                            'longitude': -79.41562,
#                            'name': 'Wells Hill Ave / St Clair Ave W',
#                            'timestamp': '2025-04-15T21:03:40.131127Z'},
#                           {'empty_slots': 20,
#                            'extra': {'address': 'Bay St / Dundas St W',
#                                      'altitude': 0.0,
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1744750893,
#                                      'normal_bikes': 32,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'post_code': 'M5G 2C3',
#                                      'rental_uris': {},
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'slots': 55,
#                                      'uid': '7816'},
#                            'free_bikes': 33,
#                            'id': 'ffeaa2aaedeb18fc11f708bcd8323149',
#                            'latitude': 43.655350778457056,
#                            'longitude': -79.38345966759798,
#                            'name': 'Bay St / Dundas St W',
#                            'timestamp': '2025-04-15T21:03:40.166566Z'}]}}

# %%
json_data = bikes.json()  # Convert response to Python dict

# Convert to DataFrame (extracting the list under 'data')
df = pd.DataFrame(json_data['network']['stations'])

print(df.head())
# Out:
#                                  id                              name  \
# 0  009f180cf35ae1285733d98ccf058313    Summerhill Ave / Maclennan Ave
# 1  010507feed5b8d87c40cd95933ed5654     Queen St E / Joseph Duggan Rd
# 2  0153756b9e136b96e730aaa2f048227f  Victoria Park Ave / Danforth Ave
# 3  019e5937c3fc120cee906770bca8fa69     Navy Wharf Crt / Bremner Blvd
# 4  01caf8b12874b091f2fccc3818e3c72e               420 Wellington St W
#
#     latitude  longitude                    timestamp  free_bikes  empty_slots  \
# 0  43.685924 -79.376304  2025-04-15T21:03:40.155472Z           0           11
# 1  43.667763 -79.308117  2025-04-15T21:03:40.159363Z          12            7
# 2  43.691468 -79.288619  2025-04-15T21:03:40.157283Z           2           17
# 3  43.640722 -79.391051  2025-04-15T21:03:40.127576Z           2            4
# 4  43.643834 -79.396649  2025-04-15T21:03:40.128763Z          13            2
#
#                                                extra
# 0  {'uid': '7488', 'renting': 1, 'returning': 1, ...
# 1  {'uid': '7695', 'renting': 1, 'returning': 1, ...
# 2  {'uid': '7611', 'renting': 1, 'returning': 1, ...
# 3  {'uid': '7054', 'renting': 1, 'returning': 1, ...
# 4  {'uid': '7123', 'renting': 1, 'returning': 1, ...

# %%
from pandas import json_normalize  # In pandas >=1.0, use pd.json_normalize()

# Normalize the 'data' key while expanding nested fields
df = json_normalize(json_data['network']['stations'])

print(df)
# Out:
#                                    id                              name  \
# 0    009f180cf35ae1285733d98ccf058313    Summerhill Ave / Maclennan Ave
# 1    010507feed5b8d87c40cd95933ed5654     Queen St E / Joseph Duggan Rd
# 2    0153756b9e136b96e730aaa2f048227f  Victoria Park Ave / Danforth Ave
# 3    019e5937c3fc120cee906770bca8fa69     Navy Wharf Crt / Bremner Blvd
# 4    01caf8b12874b091f2fccc3818e3c72e               420 Wellington St W
# ..                                ...                               ...
# 872  fe806cf907683c67f4d2899eb4123f00                     457 King St W
# 873  fe97ae335b31b6c455f340f397904d38        Danforth Ave / Coxwell Ave
# 874  fea3f9dfbcc18225728f10913c5d3d5b            Bloor St W / Brock Ave
# 875  ffc954e6f4228f59169c040483ebcc3a   Wells Hill Ave / St Clair Ave W
# 876  ffeaa2aaedeb18fc11f708bcd8323149              Bay St / Dundas St W
#
#       latitude  longitude                    timestamp  free_bikes  \
# 0    43.685924 -79.376304  2025-04-15T21:03:40.155472Z           0
# 1    43.667763 -79.308117  2025-04-15T21:03:40.159363Z          12
# 2    43.691468 -79.288619  2025-04-15T21:03:40.157283Z           2
# 3    43.640722 -79.391051  2025-04-15T21:03:40.127576Z           2
# 4    43.643834 -79.396649  2025-04-15T21:03:40.128763Z          13
# ..         ...        ...                          ...         ...
# 872  43.645209 -79.396074  2025-04-15T21:03:40.130744Z          18
# 873  43.683378 -79.322961  2025-04-15T21:03:40.127839Z           4
# 874  43.658988 -79.438715  2025-04-15T21:03:40.157929Z           1
# 875  43.683351 -79.415620  2025-04-15T21:03:40.131127Z           0
# 876  43.655351 -79.383460  2025-04-15T21:03:40.166566Z          33
#
#      empty_slots extra.uid  extra.renting  extra.returning  \
# 0             11      7488              1                1
# 1              7      7695              1                1
# 2             17      7611              1                1
# 3              4      7054              1                1
# 4              2      7123              1                1
# ..           ...       ...            ...              ...
# 872            1      7323              1                1
# 873           11      7088              1                1
# 874           10      7656              1                1
# 875           15      7363              1                1
# 876           20      7816              1                1
#
#      extra.last_updated                     extra.address extra.post_code  \
# 0            1744750915    Summerhill Ave / Maclennan Ave         M4M 2Z9
# 1            1744750998   Queen St E and Joseph Duggan Rd         M4L 3Y2
# 2            1744750898  Victoria Park Ave / Danforth Ave         M4C 1N2
# 3            1744750952    Navy Wharf Ct. / Bremner Blvd.             NaN
# 4            1744750881               420 Wellington St W             NaN
# ..                  ...                               ...             ...
# 872          1744750893                    457 King St W.             NaN
# 873          1744750983        Danforth Ave / Coxwell Ave             NaN
# 874          1744750998             Bloor St W / Brock Av         M6H 1M9
# 875          1744750955   Wells Hill Ave / St Clair Ave W             NaN
# 876          1744750893              Bay St / Dundas St W         M5G 2C3
#
#      extra.has_ebikes  extra.ebikes  extra.normal_bikes  \
# 0                True             0                   0
# 1                True             0                  12
# 2                True             0                   2
# 3                True             1                   1
# 4                True             2                  11
# ..                ...           ...                 ...
# 872              True             0                  18
# 873              True             1                   3
# 874              True             1                   0
# 875              True             0                   0
# 876              True             1                  32
#
#                              extra.payment  extra.payment-terminal  \
# 0    [key, transitcard, creditcard, phone]                    True
# 1                [key, transitcard, phone]                   False
# 2    [key, transitcard, creditcard, phone]                    True
# 3    [key, transitcard, creditcard, phone]                    True
# 4    [key, transitcard, creditcard, phone]                    True
# ..                                     ...                     ...
# 872  [key, transitcard, creditcard, phone]                    True
# 873  [key, transitcard, creditcard, phone]                    True
# 874  [key, transitcard, creditcard, phone]                    True
# 875  [key, transitcard, creditcard, phone]                    True
# 876              [key, transitcard, phone]                   False
#
#      extra.altitude  extra.slots
# 0               NaN           11
# 1               0.0           19
# 2               0.0           19
# 3               NaN            9
# 4               NaN           15
# ..              ...          ...
# 872             NaN           19
# 873             0.0           15
# 874             0.0           11
# 875             NaN           15
# 876             0.0           55
#
# [877 rows x 20 columns]

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
df2 = df.filter(['latitude','longitude','free_bikes'], axis=1)
# Out:
#       latitude  longitude  free_bikes
# 0    43.685924 -79.376304           0
# 1    43.667763 -79.308117          12
# 2    43.691468 -79.288619           2
# 3    43.640722 -79.391051           2
# 4    43.643834 -79.396649          13
# ..         ...        ...         ...
# 872  43.645209 -79.396074          18
# 873  43.683378 -79.322961           4
# 874  43.658988 -79.438715           1
# 875  43.683351 -79.415620           0
# 876  43.655351 -79.383460          33
#
# [877 rows x 3 columns]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
print(df2)
# Out:
#       latitude  longitude  free_bikes
# 0    43.685924 -79.376304           0
# 1    43.667763 -79.308117          12
# 2    43.691468 -79.288619           2
# 3    43.640722 -79.391051           2
# 4    43.643834 -79.396649          13
# ..         ...        ...         ...
# 872  43.645209 -79.396074          18
# 873  43.683378 -79.322961           4
# 874  43.658988 -79.438715           1
# 875  43.683351 -79.415620           0
# 876  43.655351 -79.383460          33
#
# [877 rows x 3 columns]

# %%
df2.to_csv(path_or_buf = '../data/bike_stations.csv')
